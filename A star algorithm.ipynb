# %%
#pip install networkx
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install matplotlib

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
def dist(a,b):
    (x1,y1)=a
    (y1,y2)=b
    return ((x1-x2)**2+(y1-y2)**2)**0.5

# %%
G=nx.grid_graph(dim=[3,3])
nx.set_edge_attributes(G,{e:e[1][0]*2 for e in G.edges()},"cost")

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos,with_labels=True,node_color="#f86e00")
edge_labels=nx.get_edge_attributes(G,"cost")
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
plt.show()

# %%
path=nx.astar_path(G,(0,0),(2,1),heuristic=dist,weight="cost")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 path=nx.astar_path(G,(0,0),(2,1),heuristic=dist,weight="cost")
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\shortest_paths\astar.py:151, in astar_path(G, source, target, heuristic, weight)
#     149         continue
#     150 else:
# --> 151     h = heuristic(neighbor, target)
#     152 enqueued[neighbor] = ncost, h
#     153 push(queue, (ncost + h, next(c), neighbor, ncost, curnode))
#
# Cell In[14], line 4, in dist(a, b)
#       2 (x1,y1)=a
#       3 (y1,y2)=b
# ----> 4 return ((x1-x2)**2+(y1-y2)**2)**0.5
#
# NameError: name 'x2' is not defined

# %%
length=nx.astar_path_length(G,(0,0),(2,1),heuristic=dist,weight="cost")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 length=nx.astar_path_length(G,(0,0),(2,1),heuristic=dist,weight="cost")
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\shortest_paths\astar.py:209, in astar_path_length(G, source, target, heuristic, weight)
#     206     raise nx.NodeNotFound(msg)
#     208 weight = _weight_function(G, weight)
# --> 209 path = astar_path(G, source, target, heuristic, weight)
#     210 return sum(weight(u, v, G[u][v]) for u, v in zip(path[:-1], path[1:]))
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\shortest_paths\astar.py:151, in astar_path(G, source, target, heuristic, weight)
#     149         continue
#     150 else:
# --> 151     h = heuristic(neighbor, target)
#     152 enqueued[neighbor] = ncost, h
#     153 push(queue, (ncost + h, next(c), neighbor, ncost, curnode))
#
# Cell In[6], line 4, in dist(a, b)
#       2 (x1,y1)=a
#       3 (y1,y2)=b
# ----> 4 return ((x1-x2)**2+(y1-y2)**2)**0.5
#
# NameError: name 'x2' is not defined

# %%
print('path:',path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print('path:',path)
#
# NameError: name 'path' is not defined

# %%
print('path length',length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print('path length',length)
#
# NameError: name 'length' is not defined
